# %% [markdown]
# <a href="https://colab.research.google.com/github/ujanichakma/AI_LAB_4-1_2025/blob/main/AI_final_assignment/AI_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.layers import Input, Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist, fashion_mnist, cifar10
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt


# ---------------- DATA LOADER ----------------
def load_dataset(name):
    if name == "mnist":
        return mnist.load_data()
    elif name == "fashion":
        return fashion_mnist.load_data()
    elif name == "cifar":
        return cifar10.load_data()


# ---------------- MODEL ----------------
def build_model(input_shape, num_classes=10):
    Inputs = Input(input_shape)

    x = Conv2D(8, (3,3), activation='relu')(Inputs)
    x = MaxPooling2D((2,2))(x)

    x = Conv2D(16, (3,3), activation='relu')(x)
    x = MaxPooling2D((2,2))(x)

    x = Flatten()(x)
    x = Dense(64, activation='relu')(x)
    x = Dense(16, activation='relu')(x)

    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(Inputs, outputs)
    model.summary()
    return model


# ---------------- MAIN ----------------
def run(dataset_name):

    (trainX, trainY), (testX, testY) = load_dataset(dataset_name)

    trainX = trainX.astype('float32') / 255.0
    testX = testX.astype('float32') / 255.0

    # Add channel if grayscale
    if len(trainX.shape) == 3:
        trainX = np.expand_dims(trainX, -1)
        testX = np.expand_dims(testX, -1)

    trainY_cat = to_categorical(trainY, 10)
    testY_cat = to_categorical(testY, 10)

    print("Train:", trainX.shape)
    print("Test:", testX.shape)

    model = build_model(trainX.shape[1:])
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(trainX, trainY_cat,
                        epochs=10,
                        batch_size=32,
                        validation_data=(testX, testY_cat))

    loss, acc = model.evaluate(testX, testY_cat)
    print(f"{dataset_name} Test Accuracy: {acc*100:.2f}%")

    plot_accuracy(history)
    plot_loss(history)

    preds = model.predict(testX)
    pred_classes = np.argmax(preds, axis=1)
    plot_predictions(testX, testY, pred_classes)


# ---------------- PLOTS ----------------
def plot_predictions(images, actual, predicted, num=25):
    plt.figure(figsize=(10,10))
    for i in range(num):
        plt.subplot(5,5,i+1)
        plt.imshow(images[i].squeeze(), cmap='gray')
        plt.title(f"T:{actual[i]} P:{predicted[i]}")
        plt.axis('off')
    plt.show()


def plot_accuracy(history):
    plt.figure()
    plt.plot(history.history['accuracy'], label='Train')
    plt.plot(history.history['val_accuracy'], label='Val')
    plt.title('Accuracy')
    plt.legend()
    plt.show()


def plot_loss(history):
    plt.figure()
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Val')
    plt.title('Loss')
    plt.legend()
    plt.show()


# -------- RUN ALL --------
run("mnist")
run("fashion")
run("cifar")
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Train: (60000, 28, 28, 1)
# Test: (10000, 28, 28, 1)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 26, 26, 8)      │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...
