# %% [markdown]
# <a href="https://colab.research.google.com/github/ujanichakma/AI_LAB_4-1_2025/blob/main/AI_final_assignment/AI_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# 1. Load Dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

y_train_cat = to_categorical(y_train, 10)
y_test_cat = to_categorical(y_test, 10)

# 2. Model Builder
def build_model(activation='relu', loss_fn='categorical_crossentropy'):
    model = models.Sequential([
        layers.Input(shape=(32,32,3)),
        layers.Conv2D(32, (3,3), activation=activation),
        layers.MaxPooling2D(2,2),
        layers.Conv2D(64, (3,3), activation=activation),
        layers.MaxPooling2D(2,2),
        layers.Flatten(),
        layers.Dense(128, activation=activation),
        layers.Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss=loss_fn,
        metrics=['accuracy']
    )
    return model

# 3. Experiments
configs = [
    ('relu', 'categorical_crossentropy'),
    ('tanh', 'categorical_crossentropy'),
    ('relu', 'mean_squared_error'),
]

for act, loss in configs:
    print(f"\nTraining with Activation={act}, Loss={loss}")
    model = build_model(act, loss)

    if loss == 'categorical_crossentropy':
        model.fit(x_train, y_train_cat, epochs=5,
                  validation_data=(x_test, y_test_cat), batch_size=64)
    else:
        model.fit(x_train, y_train_cat, epochs=5,
                  validation_data=(x_test, y_test_cat), batch_size=64)

    test_loss, test_acc = model.evaluate(x_test, y_test_cat)
    print("Test Accuracy:", test_acc)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
#
# Training with Activation=relu, Loss=categorical_crossentropy
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.3797 - loss: 1.7075 - val_accuracy: 0.5456 - val_loss: 1.2806
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.5856 - loss: 1.1685 - val_accuracy: 0.6038 - val_loss: 1.1472
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6402 - loss: 1.0277 - val_accuracy: 0.6675 - val_loss: 0.9684
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6802 - loss: 0.9125 - val_accuracy: 0.6541 - val_loss: 0.9707
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7123 - loss: 0.8195 - val_accuracy: 0.6823 - val_loss: 0.9308
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6877 - loss: 0.9217
# Test Accuracy: 0.6822999715805054
#
# Training with Activation=tanh, Loss=categorical_crossentropy
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.4197 - loss: 1.6323 - val_accuracy: 0.5876 - val_loss: 1.1922
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.6103 - loss: 1.1212 - val_accuracy: 0.6302 - val_loss: 1.0657
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6553 - loss: 0.9905 - val_accuracy: 0.6525 - val_loss: 0.9973
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7010 - loss: 0.8595 - val_accuracy: 0.6684 - val_loss: 0.9602
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7377 - loss: 0.7627 - val_accuracy: 0.6681 - val_loss: 0.9747
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6664 - loss: 0.9650
# Test Accuracy: 0.6680999994277954
#
# Training with Activation=relu, Loss=mean_squared_error
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.3655 - loss: 0.0747 - val_accuracy: 0.5601 - val_loss: 0.0575
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5847 - loss: 0.0547 - val_accuracy: 0.6085 - val_loss: 0.0523
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.6527 - loss: 0.0473 - val_accuracy: 0.6611 - val_loss: 0.0456
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6882 - loss: 0.0429 - val_accuracy: 0.6728 - val_loss: 0.0443
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7226 - loss: 0.0390 - val_accuracy: 0.6859 - val_loss: 0.0435
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6898 - loss: 0.0430
# Test Accuracy: 0.6858999729156494
